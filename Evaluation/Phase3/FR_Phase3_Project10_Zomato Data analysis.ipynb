# %% [markdown]
# ### Project Description
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
# • Country code
# • Country name

# %% [markdown]
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
#     • Restaurant Id: Unique id of every restaurant across various cities of the world
#     • Restaurant Name: Name of the restaurant
#     • Country Code: Country in which restaurant is located
#     • City: City in which restaurant is located
#     • Address: Address of the restaurant
#     • Locality: Location in the city
#     • Locality Verbose: Detailed description of the locality
#     • Longitude: Longitude coordinate of the restaurant&#39;s location
#     • Latitude: Latitude coordinate of the restaurant&#39;s location
#     • Cuisines: Cuisines offered by the restaurant
#     • Average Cost for two: Cost for two people in different currencies
#     • Currency: Currency of the country
#     • Has Table booking: yes/no
#     • Has Online delivery: yes/ no
#     • Is delivering: yes/ no
#     • Switch to order menu: yes/no
#     • Price range: range of price of food
#     • Aggregate Rating: Average rating out of 5
#     • Rating color: depending upon the average rating color
#     • Rating text: text on the basis of rating of rating
#     • Votes: Number of ratings casted by people
#
# Problem statement : In this dataset predict 2 things –
#
#     1) Average Cost for two
#
#     2) Price range
#
#
# Hint : Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets
#
# Dataset Link-
# •	https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
#
# •	https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
df_country=pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_zomato=pd.read_excel('zomato1.xlsx')
df_zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df_country.shape
# Out:
# (15, 2)

# %%
df_zomato.shape
# Out:
# (9551, 21)

# %%
df = pd.merge(df_zomato, df_country, how="left", on=["Country Code"])

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...  Has Table booking  \
# 0        French, Japanese, Desserts  ...                Yes
# 1                          Japanese  ...                Yes
# 2  Seafood, Asian, Filipino, Indian  ...                Yes
# 3                   Japanese, Sushi  ...                 No
# 4                  Japanese, Korean  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#   Aggregate rating  Rating color  Rating text Votes      Country
# 0              4.8    Dark Green    Excellent   314  Phillipines
# 1              4.5    Dark Green    Excellent   591  Phillipines
# 2              4.4         Green    Very Good   270  Phillipines
# 3              4.9    Dark Green    Excellent   365  Phillipines
# 4              4.8    Dark Green    Excellent   229  Phillipines
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#drops rows with null value
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
#  15  Switch to order menu  9542 non-null   object
#  16  Price range           9542 non-null   int64
#  17  Aggregate rating      9542 non-null   float64
#  18  Rating color          9542 non-null   object
#  19  Rating text           9542 non-null   object
#  20  Votes                 9542 non-null   int64
#  21  Country               9542 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#droping unwanted columns
df.drop(['Restaurant ID','Is delivering now','Switch to order menu'],axis=1,inplace=True)

# %%
df['Country Code'].nunique()
df['Country Code'].value_counts()
# Out:
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
df.drop(columns=['Restaurant Name','Country Code','Currency'],inplace=True)

# %%
df['City'].value_counts()
# Out:
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lincoln              1
# Lakeview             1
# Lakes Entrance       1
# Inverloch            1
# Panchkula            1
# Name: City, Length: 140, dtype: int64

# %%
city_names=df.City.value_counts().index
# display(city_names)
city_values=df.City.value_counts().values
# city_values

# %%
plt.pie(city_values[:5],labels=city_names[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25c9a4a7df0>,
#   <matplotlib.patches.Wedge at 0x25c9a8134c0>,
#   <matplotlib.patches.Wedge at 0x25c9a813b50>,
#   <matplotlib.patches.Wedge at 0x25c9a832220>,
#   <matplotlib.patches.Wedge at 0x25c9a8328b0>],
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %%
df['Locality'].value_counts()
# Out:
# Connaught Place                                122
# Rajouri Garden                                  99
# Shahdara                                        87
# Defence Colony                                  86
# Pitampura                                       85
#                                               ...
# Omaxe Celebration Mall, Sohna Road, Gurgaon      1
# Park Inn, Sector 15, Gurgaon                     1
# Plaza Mall, MG Road                              1
# Ramada Gurgaon Central, Sector 44                1
# Moda                                             1
# Name: Locality, Length: 1206, dtype: int64

# %%
df['Locality Verbose'].value_counts()
# Out:
# Connaught Place, New Delhi                    122
# Rajouri Garden, New Delhi                      99
# Shahdara, New Delhi                            87
# Defence Colony, New Delhi                      86
# Pitampura, New Delhi                           85
#                                              ...
# Ramada Gurgaon Central, Sector 44, Gurgaon      1
# Sector 5, Gurgaon                               1
# Sector 53, Gurgaon                              1
# The Claremont, MG Road, Gurgaon                 1
# Moda, ÛÁstanbul                                 1
# Name: Locality Verbose, Length: 1263, dtype: int64

# %%
top_cuisines_df=df['Cuisines'].value_counts().head(10)
plt.pie(top_cuisines_df,labels=top_cuisines_df,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25c9a4819d0>,
#   <matplotlib.patches.Wedge at 0x25c9a0faf10>,
#   <matplotlib.patches.Wedge at 0x25c9a0f9be0>,
#   <matplotlib.patches.Wedge at 0x25c9a47e190>,
#   <matplotlib.patches.Wedge at 0x25c9a6658b0>,
#   <matplotlib.patches.Wedge at 0x25c9a665f70>,
#   <matplotlib.patches.Wedge at 0x25c9a67f640>,
#   <matplotlib.patches.Wedge at 0x25c9a67fcd0>,
#   <matplotlib.patches.Wedge at 0x25c9a68f3a0>,
#   <matplotlib.patches.Wedge at 0x25c9a68fa30>],
#  [Text(0.7383739846958008, 0.8153550507137645, '936'),
#   Text(-0.5794679314239953, 0.9349956772366362, '511'),
#   Text(-1.067309479615702, 0.26617752482593154, '354'),
#   Text(-1.0185984499802057, -0.4152796620326146, '354'),
#   Text(-0.5935788454809928, -0.9261015895664211, '334'),
#   Text(-0.005887079599915552, -1.0999842463843672, '299'),
#   Text(0.4842062514572988, -0.9876964645323336, '218'),
#   Text(0.808736477166136, -0.7456174022251013, '197'),
#   Text(1.0055375294202338, -0.44597564611473206, '170'),
#   Text(1.090298995560443, -0.14576728123927227, '149')],
#  [Text(0.4027494461977095, 0.4447391185711442, '26.58%'),
#   Text(-0.316073417140361, 0.5099976421290743, '14.51%'),
#   Text(-0.5821688070631101, 0.14518774081414446, '10.05%'),
#   Text(-0.5555991545346576, -0.22651617929051704, '10.05%'),
#   Text(-0.32377027935326874, -0.5051463215816842, '9.48%'),
#   Text(-0.003211134327226664, -0.5999914071187457, '8.49%'),
#   Text(0.26411250079489024, -0.5387435261085456, '6.19%'),
#   Text(0.441128987545165, -0.40670040121369155, '5.59%'),
#   Text(0.5484750160474001, -0.24325944333530836, '4.83%'),
#   Text(0.5947085430329688, -0.07950942613051214, '4.23%')])

# %%
popular_cuisines=df['Cuisines'].value_counts()[:10].rename_axis('Cuisines').reset_index(name='count')
popular_cuisines.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_59431_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_59431_row1_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_59431_row2_col1, #T_59431_row3_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_59431_row4_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_59431_row5_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_59431_row6_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_59431_row7_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_59431_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_59431_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_59431">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59431_level0_col0" class="col_heading level0 col0" >Cuisines</th>
#       <th id="T_59431_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59431_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59431_row0_col0" class="data row0 col0" >North Indian</td>
#       <td id="T_59431_row0_col1" class="data row0 col1" >936</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59431_row1_col0" class="data row1 col0" >North Indian, Chinese</td>
#       <td id="T_59431_row1_col1" class="data row1 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59431_row2_col0" class="data row2 col0" >Chinese</td>
#       <td id="T_59431_row2_col1" class="data row2 col1" >354</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59431_row3_col0" class="data row3 col0" >Fast Food</td>
#       <td id="T_59431_row3_col1" class="data row3 col1" >354</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_59431_row4_col0" class="data row4 col0" >North Indian, Mughlai</td>
#       <td id="T_59431_row4_col1" class="data row4 col1" >334</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_59431_row5_col0" class="data row5 col0" >Cafe</td>
#       <td id="T_59431_row5_col1" class="data row5 col1" >299</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_59431_row6_col0" class="data row6 col0" >Bakery</td>
#       <td id="T_59431_row6_col1" class="data row6 col1" >218</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_59431_row7_col0" class="data row7 col0" >North Indian, Mughlai, Chinese</td>
#       <td id="T_59431_row7_col1" class="data row7 col1" >197</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_59431_row8_col0" class="data row8 col0" >Bakery, Desserts</td>
#       <td id="T_59431_row8_col1" class="data row8 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_59431_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_59431_row9_col0" class="data row9 col0" >Street Food</td>
#       <td id="T_59431_row9_col1" class="data row9 col1" >149</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.title("Most popular Cuisines")   #add title

sns.scatterplot(y=popular_cuisines['Cuisines'],x=popular_cuisines['count'],hue=popular_cuisines['Cuisines'])
# Out:
# <AxesSubplot: title={'center': 'Most popular Cuisines'}, xlabel='count', ylabel='Cuisines'>

# %%
# Analysing 'Rating color' column

sns.countplot(x='Rating color',data=df,palette=['darkgreen','green','yellow','orange','grey','red'])
# Out:
# <AxesSubplot: xlabel='Rating color', ylabel='count'>

# %%
# Analysing 'Rating text' column

plt.title("Rating text vs Average Cost for two")     #Add title
sns.barplot(x=df['Rating text'],y=df['Average Cost for two'],palette=['cyan','orange', 'red', 'green', 'blue','grey'])
# Out:
# <AxesSubplot: title={'center': 'Rating text vs Average Cost for two'}, xlabel='Rating text', ylabel='Average Cost for two'>

# %%
df['Cuisines']
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9542, dtype: object

# %%
df.groupby('Cuisines').mean()
# Out:
#                                             Longitude   Latitude  \
# Cuisines
# Afghani                                     77.145669  28.507631
# Afghani, Mughlai, Chinese                   77.245796  28.558387
# Afghani, North Indian                       77.045289  28.439285
# Afghani, North Indian, Pakistani, Arabian   77.266754  28.659755
# African                                     28.236047 -25.770748
# ...                                               ...        ...
# Western, Asian, Cafe                       106.911335  -6.163948
# Western, Fusion, Fast Food                 103.858430   1.301707
# World Cuisine                               32.869800  39.898239
# World Cuisine, Mexican, Italian             32.865683  39.897872
# World Cuisine, Patisserie, Cafe             29.041297  41.009847
#
#                                            Average Cost for two  Price range  \
# Cuisines
# Afghani                                                   512.5         1.75
# Afghani, Mughlai, Chinese                                 500.0         2.00
# Afghani, North Indian                                     900.0         2.00
# Afghani, North Indian, Pakistani, Arabian                 500.0         2.00
# African                                                   450.0         4.00
# ...                                                         ...          ...
# Western, Asian, Cafe                                   250000.0         3.00
# Western, Fusion, Fast Food                                 60.0         4.00
# World Cuisine                                              80.0         3.00
# World Cuisine, Mexican, Italian                           150.0         4.00
# World Cuisine, Patisserie, Cafe                           105.0         3.00
#
#                                            Aggregate rating    Votes
# Cuisines
# Afghani                                               0.725     9.75
# Afghani, Mughlai, Chinese                             0.000     2.00
# Afghani, North Indian                                 0.000     0.00
# Afghani, North Indian, Pakistani, Arabian             0.000     3.00
# African                                               4.700   373.00
# ...                                                     ...      ...
# Western, Asian, Cafe                                  4.200   259.00
# Western, Fusion, Fast Food                            3.200    32.00
# World Cuisine                                         4.900    95.00
# World Cuisine, Mexican, Italian                       4.400   115.00
# World Cuisine, Patisserie, Cafe                       4.200  1034.00
#
# [1825 rows x 6 columns]

# %%
df.groupby('Cuisines').mean()['Average Cost for two'].sort_values(ascending=False)
# Out:
# Cuisines
# Asian, Indonesian, Western                                    800000.0
# French, Western                                               350000.0
# Cafe, Western                                                 300000.0
# Indonesian                                                    300000.0
# Sushi, Japanese                                               250060.0
#                                                                 ...
# Burger, Coffee and Tea, Modern Australian                          7.0
# Desserts, Pizza, Ice Cream                                         0.0
# Indian, Chinese, Continental                                       0.0
# Cafe, Italian, Mexican, North Indian, Continental                  0.0
# Cafe, Continental, Desserts, Ice Cream, Italian, Beverages         0.0
# Name: Average Cost for two, Length: 1825, dtype: float64

# %%
avg_price=df.groupby('Cuisines').mean()['Average Cost for two'].reset_index()
avg_price
# Out:
#                                        Cuisines  Average Cost for two
# 0                                       Afghani                 512.5
# 1                     Afghani, Mughlai, Chinese                 500.0
# 2                         Afghani, North Indian                 900.0
# 3     Afghani, North Indian, Pakistani, Arabian                 500.0
# 4                                       African                 450.0
# ...                                         ...                   ...
# 1820                       Western, Asian, Cafe              250000.0
# 1821                 Western, Fusion, Fast Food                  60.0
# 1822                              World Cuisine                  80.0
# 1823            World Cuisine, Mexican, Italian                 150.0
# 1824            World Cuisine, Patisserie, Cafe                 105.0
#
# [1825 rows x 2 columns]

# %%
# to create a table with selected features for better understanding
df.groupby(['Rating color','Aggregate rating','Rating text']).mean().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_68bd7_row0_col0, #T_68bd7_row3_col1, #T_68bd7_row21_col2, #T_68bd7_row27_col2, #T_68bd7_row27_col3, #T_68bd7_row27_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_68bd7_row0_col1, #T_68bd7_row6_col3, #T_68bd7_row30_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_68bd7_row0_col2, #T_68bd7_row12_col2, #T_68bd7_row16_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_68bd7_row0_col3 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_68bd7_row0_col4 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_68bd7_row1_col0, #T_68bd7_row11_col4, #T_68bd7_row12_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_68bd7_row1_col1, #T_68bd7_row22_col3 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_68bd7_row1_col2 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_68bd7_row1_col3, #T_68bd7_row4_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_68bd7_row1_col4 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_68bd7_row2_col0, #T_68bd7_row22_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_68bd7_row2_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_68bd7_row2_col2, #T_68bd7_row10_col2, #T_68bd7_row11_col2, #T_68bd7_row14_col4, #T_68bd7_row17_col2, #T_68bd7_row18_col2, #T_68bd7_row24_col2, #T_68bd7_row25_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_68bd7_row2_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_68bd7_row2_col4 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_68bd7_row3_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_68bd7_row3_col2, #T_68bd7_row28_col2, #T_68bd7_row29_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_68bd7_row3_col3, #T_68bd7_row3_col4, #T_68bd7_row4_col2, #T_68bd7_row11_col0, #T_68bd7_row12_col1, #T_68bd7_row20_col1, #T_68bd7_row21_col1, #T_68bd7_row23_col1, #T_68bd7_row25_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_68bd7_row4_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_68bd7_row4_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_68bd7_row4_col3, #T_68bd7_row28_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_68bd7_row5_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_68bd7_row5_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_68bd7_row5_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_68bd7_row5_col3 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_68bd7_row5_col4 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_68bd7_row6_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_68bd7_row6_col1 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_68bd7_row6_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_68bd7_row6_col4 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_68bd7_row7_col0, #T_68bd7_row28_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_68bd7_row7_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_68bd7_row7_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_68bd7_row7_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_68bd7_row7_col4 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_68bd7_row8_col0, #T_68bd7_row23_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_68bd7_row8_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_68bd7_row8_col2, #T_68bd7_row31_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_68bd7_row8_col3 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_68bd7_row8_col4 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_68bd7_row9_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_68bd7_row9_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_68bd7_row9_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_68bd7_row9_col3 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_68bd7_row9_col4 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_68bd7_row10_col0, #T_68bd7_row20_col0, #T_68bd7_row22_col0, #T_68bd7_row22_col1, #T_68bd7_row24_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_68bd7_row10_col1 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_68bd7_row10_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_68bd7_row10_col4, #T_68bd7_row23_col4, #T_68bd7_row32_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_68bd7_row11_col1, #T_68bd7_row13_col0 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_68bd7_row11_col3 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_68bd7_row12_col0, #T_68bd7_row13_col1, #T_68bd7_row21_col0, #T_68bd7_row23_col0 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_68bd7_row12_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_68bd7_row13_col2, #T_68bd7_row14_col2, #T_68bd7_row15_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_68bd7_row13_col3 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_68bd7_row13_col4, #T_68bd7_row16_col4, #T_68bd7_row19_col2, #T_68bd7_row31_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_68bd7_row14_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_68bd7_row14_col1, #T_68bd7_row18_col1, #T_68bd7_row26_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_68bd7_row14_col3 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_68bd7_row15_col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_68bd7_row15_col1, #T_68bd7_row16_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_68bd7_row15_col3, #T_68bd7_row28_col4 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_68bd7_row15_col4, #T_68bd7_row23_col2, #T_68bd7_row26_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_68bd7_row16_col1, #T_68bd7_row18_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_68bd7_row16_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_68bd7_row17_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_68bd7_row17_col1, #T_68bd7_row29_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_68bd7_row17_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_68bd7_row17_col4, #T_68bd7_row20_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_68bd7_row18_col3 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_68bd7_row18_col4 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_68bd7_row19_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_68bd7_row19_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_68bd7_row19_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_68bd7_row19_col4, #T_68bd7_row24_col4, #T_68bd7_row26_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_68bd7_row20_col3, #T_68bd7_row25_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_68bd7_row20_col4 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_68bd7_row21_col3 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_68bd7_row21_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_68bd7_row22_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_68bd7_row24_col0, #T_68bd7_row28_col1, #T_68bd7_row30_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_68bd7_row24_col3 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_68bd7_row25_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_68bd7_row25_col4 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_68bd7_row26_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_68bd7_row26_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_68bd7_row27_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_68bd7_row27_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_68bd7_row29_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_68bd7_row29_col3 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_68bd7_row29_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_68bd7_row30_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_68bd7_row30_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_68bd7_row30_col4 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_68bd7

# %%
df=df.merge(avg_price, on='Cuisines')
df.head(5)
# Out:
#              City                                            Address  \
# 0     Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2       Brasí_lia      SCS 213, Bloco C, Loja 35, Asa Sul, Brasí_lia
# 3       Brasí_lia      SCS 212, Bloco B, Loja 26, Asa Sul, Brasí_lia
# 4  Rio de Janeiro     Rua Dias Ferreira, 256, Leblon, Rio de Janeiro
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2                                     Asa Sul
# 3                                     Asa Sul
# 4                                      Leblon
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2                                 Asa Sul, Brasí_lia  -47.915667 -15.831000
# 3                                 Asa Sul, Brasí_lia  -47.910167 -15.827333
# 4                             Leblon, Rio de Janeiro  -43.227000 -22.984167
#
#                      Cuisines  Average Cost for two_x Has Table booking  \
# 0  French, Japanese, Desserts                    1100               Yes
# 1                    Japanese                    1200               Yes
# 2                    Japanese                      80                No
# 3                    Japanese                     200                No
# 4                    Japanese                     250                No
#
#   Has Online delivery  Price range  Aggregate rating Rating color Rating text  \
# 0                  No            3               4.8   Dark Green   Excellent
# 1                  No            3               4.5   Dark Green   Excellent
# 2                  No            3               3.1       Orange     Average
# 3                  No            4               3.7       Yellow        Good
# 4                  No            4               4.6   Dark Green   Excellent
#
#    Votes      Country  Average Cost for two_y
# 0    314  Phillipines             1100.000000
# 1    591  Phillipines            27488.235294
# 2     10       Brazil            27488.235294
# 3      5       Brazil            27488.235294
# 4     25       Brazil            27488.235294

# %%
df.rename(columns={'Average Cost for two_y':'Cuisine','Average Cost for two_x':'target'}, inplace=True)
df.head(1)
# Out:
#           City                                            Address  \
# 0  Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  target Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts    1100               Yes                  No
#
#    Price range  Aggregate rating Rating color Rating text  Votes      Country  \
# 0            3               4.8   Dark Green   Excellent    314  Phillipines
#
#    Cuisine
# 0   1100.0

# %%
df.columns
# Out:
# Index(['City', 'Address', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'target', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Country', 'Cuisine'],
#       dtype='object')

# %%
df.drop(columns=['Address','Locality','Locality Verbose','Cuisines'],inplace=True)

# %%
plt.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Aggregate rating",y="Rating text",hue="Aggregate rating",data=df,palette=["purple","red","orange","yellow","green","green"])
# Out:
# <AxesSubplot: xlabel='Aggregate rating', ylabel='Rating text'>

# %%
df.head(1)
# Out:
#           City   Longitude   Latitude  target Has Table booking  \
# 0  Makati City  121.027535  14.565443    1100               Yes
#
#   Has Online delivery  Price range  Aggregate rating Rating color Rating text  \
# 0                  No            3               4.8   Dark Green   Excellent
#
#    Votes      Country  Cuisine
# 0    314  Phillipines   1100.0

# %%
# Review descriptive data
df.describe()
# Out:
#          Longitude     Latitude         target  Price range  Aggregate rating  \
# count  9542.000000  9542.000000    9542.000000  9542.000000       9542.000000
# mean     64.274997    25.848532    1200.326137     1.804968          2.665238
# std      41.197602    11.010094   16128.743876     0.905563          1.516588
# min    -157.948486   -41.330428       0.000000     1.000000          0.000000
# 25%      77.081565    28.478658     250.000000     1.000000          2.500000
# 50%      77.192031    28.570444     400.000000     2.000000          3.200000
# 75%      77.282043    28.642711     700.000000     2.000000          3.700000
# max     174.832089    55.976980  800000.000000     4.000000          4.900000
#
#               Votes        Cuisine
# count   9542.000000    9542.000000
# mean     156.772060    1200.326137
# std      430.203324   12912.480938
# min        0.000000       0.000000
# 25%        5.000000     332.408257
# 50%       31.000000     457.142857
# 75%      130.000000     650.000000
# max    10934.000000  800000.000000

# %%
df['Has Table booking'].replace("No",0,inplace=True)
df['Has Table booking'].replace("Yes",1,inplace=True)

# %%
df.head()
# Out:
#              City   Longitude   Latitude  target  Has Table booking  \
# 0     Makati City  121.027535  14.565443    1100                  1
# 1     Makati City  121.014101  14.553708    1200                  1
# 2       Brasí_lia  -47.915667 -15.831000      80                  0
# 3       Brasí_lia  -47.910167 -15.827333     200                  0
# 4  Rio de Janeiro  -43.227000 -22.984167     250                  0
#
#   Has Online delivery  Price range  Aggregate rating Rating color Rating text  \
# 0                  No            3               4.8   Dark Green   Excellent
# 1                  No            3               4.5   Dark Green   Excellent
# 2                  No            3               3.1       Orange     Average
# 3                  No            4               3.7       Yellow        Good
# 4                  No            4               4.6   Dark Green   Excellent
#
#    Votes      Country       Cuisine
# 0    314  Phillipines   1100.000000
# 1    591  Phillipines  27488.235294
# 2     10       Brazil  27488.235294
# 3      5       Brazil  27488.235294
# 4     25       Brazil  27488.235294

# %%
sns.countplot(x='Has Online delivery',data=df,palette=['red','green'])
# Out:
# <AxesSubplot: xlabel='Has Online delivery', ylabel='count'>

# %%
df['Has Online delivery'].replace("No",0,inplace=True)
df['Has Online delivery'].replace("Yes",1,inplace=True)
df
# Out:
#                 City   Longitude   Latitude  target  Has Table booking  \
# 0        Makati City  121.027535  14.565443    1100                  1
# 1        Makati City  121.014101  14.553708    1200                  1
# 2          Brasí_lia  -47.915667 -15.831000      80                  0
# 3          Brasí_lia  -47.910167 -15.827333     200                  0
# 4     Rio de Janeiro  -43.227000 -22.984167     250                  0
# ...              ...         ...        ...     ...                ...
# 9537       ÛÁstanbul   29.036019  41.057979     120                  0
# 9538       ÛÁstanbul   28.977636  41.022904      40                  0
# 9539       ÛÁstanbul   28.981103  41.025785      90                  0
# 9540       ÛÁstanbul   29.041297  41.009847     105                  0
# 9541       ÛÁstanbul   29.034640  41.055817     170                  0
#
#       Has Online delivery  Price range  Aggregate rating Rating color  \
# 0                       0            3               4.8   Dark Green
# 1                       0            3               4.5   Dark Green
# 2                       0            3               3.1       Orange
# 3                       0            4               3.7       Yellow
# 4                       0            4               4.6   Dark Green
# ...                   ...          ...               ...          ...
# 9537                    0            4               4.0        Green
# 9538                    0            2               4.7   Dark Green
# 9539                    0            3               4.3        Green
# 9540                    0            3               4.2        Green
# 9541                    0            4               3.7       Yellow
#
#      Rating text  Votes      Country       Cuisine
# 0      Excellent    314  Phillipines   1100.000000
# 1      Excellent    591  Phillipines  27488.235294
# 2        Average     10       Brazil  27488.235294
# 3           Good      5       Brazil  27488.235294
# 4      Excellent     25       Brazil  27488.235294
# ...          ...    ...          ...           ...
# 9537   Very Good    901       Turkey    100.000000
# 9538   Excellent   1305       Turkey     40.000000
# 9539   Very Good    870       Turkey     90.000000
# 9540   Very Good   1034       Turkey    105.000000
# 9541        Good    661       Turkey    170.000000
#
# [9542 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['City', 'Longitude', 'Latitude', 'target', 'Has Table booking',
#        'Has Online delivery', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Country', 'Cuisine'],
#       dtype='object')

# %%
df.corr()
# Out:
#                      Longitude  Latitude    target  Has Table booking  \
# Longitude             1.000000  0.045415  0.045948           0.099860
# Latitude              0.045415  1.000000 -0.111080           0.054874
# target                0.045948 -0.111080  1.000000           0.007733
# Has Table booking     0.099860  0.054874  0.007733           1.000000
# Has Online delivery   0.177922  0.119087 -0.019017           0.101041
# Price range          -0.080257 -0.166735  0.075111           0.502166
# Aggregate rating     -0.114733  0.000197  0.051864           0.190351
# Votes                -0.084371 -0.022914  0.067833           0.169619
# Cuisine               0.032149 -0.112494  0.800588           0.019481
#
#                      Has Online delivery  Price range  Aggregate rating  \
# Longitude                       0.177922    -0.080257         -0.114733
# Latitude                        0.119087    -0.166735          0.000197
# target                         -0.019017     0.075111          0.051864
# Has Table booking               0.101041     0.502166          0.190351
# Has Online delivery             1.000000     0.077887          0.226250
# Price range                     0.077887     1.000000          0.438356
# Aggregate rating                0.226250     0.438356          1.000000
# Votes                           0.074532     0.309474          0.313474
# Cuisine                        -0.021689     0.088310          0.055028
#
#                         Votes   Cuisine
# Longitude           -0.084371  0.032149
# Latitude            -0.022914 -0.112494
# target               0.067833  0.800588
# Has Table booking    0.169619  0.019481
# Has Online delivery  0.074532 -0.021689
# Price range          0.309474  0.088310
# Aggregate rating     0.313474  0.055028
# Votes                1.000000  0.063740
# Cuisine              0.063740  1.000000

# %%
df.drop(columns=['Rating color','Has Online delivery'],inplace=True)

# %%
y=df['target'].values
y
# Out:
# array([1100, 1200,   80, ...,   90,  105,  170], dtype=int64)

# %%
input1=df.drop(columns=['target'])
input1
# Out:
#                 City   Longitude   Latitude  Has Table booking  Price range  \
# 0        Makati City  121.027535  14.565443                  1            3
# 1        Makati City  121.014101  14.553708                  1            3
# 2          Brasí_lia  -47.915667 -15.831000                  0            3
# 3          Brasí_lia  -47.910167 -15.827333                  0            4
# 4     Rio de Janeiro  -43.227000 -22.984167                  0            4
# ...              ...         ...        ...                ...          ...
# 9537       ÛÁstanbul   29.036019  41.057979                  0            4
# 9538       ÛÁstanbul   28.977636  41.022904                  0            2
# 9539       ÛÁstanbul   28.981103  41.025785                  0            3
# 9540       ÛÁstanbul   29.041297  41.009847                  0            3
# 9541       ÛÁstanbul   29.034640  41.055817                  0            4
#
#       Aggregate rating Rating text  Votes      Country       Cuisine
# 0                  4.8   Excellent    314  Phillipines   1100.000000
# 1                  4.5   Excellent    591  Phillipines  27488.235294
# 2                  3.1     Average     10       Brazil  27488.235294
# 3                  3.7        Good      5       Brazil  27488.235294
# 4                  4.6   Excellent     25       Brazil  27488.235294
# ...                ...         ...    ...          ...           ...
# 9537               4.0   Very Good    901       Turkey    100.000000
# 9538               4.7   Excellent   1305       Turkey     40.000000
# 9539               4.3   Very Good    870       Turkey     90.000000
# 9540               4.2   Very Good   1034       Turkey    105.000000
# 9541               3.7        Good    661       Turkey    170.000000
#
# [9542 rows x 10 columns]

# %%
X=input1.iloc[:,:].values
X
# Out:
# array([['Makati City', 121.027535, 14.565443, ..., 314, 'Phillipines',
#         1100.0],
#        ['Makati City', 121.014101, 14.553708, ..., 591, 'Phillipines',
#         27488.235294117647],
#        ['Brasí_lia', -47.91566667, -15.831, ..., 10, 'Brazil',
#         27488.235294117647],
#        ...,
#        ['ÛÁstanbul', 28.98110311, 41.02578494, ..., 870, 'Turkey', 90.0],
#        ['ÛÁstanbul', 29.04129725, 41.00984672, ..., 1034, 'Turkey',
#         105.0],
#        ['ÛÁstanbul', 29.03464001, 41.05581715, ..., 661, 'Turkey', 170.0]],
#       dtype=object)

# %%
X.shape,y.shape
# Out:
# ((9542, 10), (9542,))

# %% [markdown]
# # Top 3 countries that uses zomato

# %%
top_3 = df['Country'].value_counts()[:3]
top_3
# Out:
# India             8652
# United States      425
# United Kingdom      80
# Name: Country, dtype: int64

# %%
plt.pie(top_3,labels=top_3.index)                  #Plotting Pie Chart
circle = plt.Circle( (0,0), 0.5, color='white')    #Creating a Circle 
p=plt.gcf()                                        #Adding circle to the Pie Chart
p.gca().add_artist(circle)
plt.title("Top 3 countries that uses zomato")      #Add title

plt.show()

# %% [markdown]
# The top 3 countries that uses zomato are India, United States and United Kingdom

# %% [markdown]
# # Top 10 countries that uses zomato

# %%
top_10 = df['Country'].value_counts()[:10].rename_axis('Country').reset_index(name='count')
top_10.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_719f5_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_719f5_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_719f5_row2_col1, #T_719f5_row3_col1, #T_719f5_row4_col1, #T_719f5_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_719f5_row6_col1, #T_719f5_row7_col1, #T_719f5_row8_col1, #T_719f5_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_719f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_719f5_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_719f5_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_719f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_719f5_row0_col0" class="data row0 col0" >India</td>
#       <td id="T_719f5_row0_col1" class="data row0 col1" >8652</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_719f5_row1_col0" class="data row1 col0" >United States</td>
#       <td id="T_719f5_row1_col1" class="data row1 col1" >425</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_719f5_row2_col0" class="data row2 col0" >United Kingdom</td>
#       <td id="T_719f5_row2_col1" class="data row2 col1" >80</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_719f5_row3_col0" class="data row3 col0" >Brazil</td>
#       <td id="T_719f5_row3_col1" class="data row3 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_719f5_row4_col0" class="data row4 col0" >UAE</td>
#       <td id="T_719f5_row4_col1" class="data row4 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_719f5_row5_col0" class="data row5 col0" >South Africa</td>
#       <td id="T_719f5_row5_col1" class="data row5 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_719f5_row6_col0" class="data row6 col0" >New Zealand</td>
#       <td id="T_719f5_row6_col1" class="data row6 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_719f5_row7_col0" class="data row7 col0" >Turkey</td>
#       <td id="T_719f5_row7_col1" class="data row7 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_719f5_row8_col0" class="data row8 col0" >Australia</td>
#       <td id="T_719f5_row8_col1" class="data row8 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_719f5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_719f5_row9_col0" class="data row9 col0" >Phillipines</td>
#       <td id="T_719f5_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Countries with minimun transactions

# %%
df['Country'].value_counts()[-3:].rename_axis('Country').reset_index(name='count').style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_8da3d_row0_col1, #T_8da3d_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8da3d_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_8da3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8da3d_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_8da3d_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8da3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8da3d_row0_col0" class="data row0 col0" >Sri Lanka</td>
#       <td id="T_8da3d_row0_col1" class="data row0 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_8da3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8da3d_row1_col0" class="data row1 col0" >Singapore</td>
#       <td id="T_8da3d_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_8da3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8da3d_row2_col0" class="data row2 col0" >Canada</td>
#       <td id="T_8da3d_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Combining different features

# %%
df.head()
# Out:
#              City   Longitude   Latitude  target  Has Table booking  \
# 0     Makati City  121.027535  14.565443    1100                  1
# 1     Makati City  121.014101  14.553708    1200                  1
# 2       Brasí_lia  -47.915667 -15.831000      80                  0
# 3       Brasí_lia  -47.910167 -15.827333     200                  0
# 4  Rio de Janeiro  -43.227000 -22.984167     250                  0
#
#    Price range  Aggregate rating Rating text  Votes      Country       Cuisine
# 0            3               4.8   Excellent    314  Phillipines   1100.000000
# 1            3               4.5   Excellent    591  Phillipines  27488.235294
# 2            3               3.1     Average     10       Brazil  27488.235294
# 3            4               3.7        Good      5       Brazil  27488.235294
# 4            4               4.6   Excellent     25       Brazil  27488.235294

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
df.head(1)
# Out:
#           City   Longitude   Latitude  target  Has Table booking  Price range  \
# 0  Makati City  121.027535  14.565443    1100                  1            3
#
#    Aggregate rating Rating text  Votes      Country  Cuisine
# 0               4.8   Excellent    314  Phillipines   1100.0

# %%
# Label Encoding : Changing columns from Category to Label
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
X[:,0]=encoder.fit_transform(X[:,0])
X[0]
X[:,-3]=encoder.fit_transform(X[:,-3])
X[0]
# Out:
# array([73, 121.027535, 14.565443, 1, 3, 4.8, 'Excellent', 314,
#        'Phillipines', 1100.0], dtype=object)

# %%
df.head()
# Out:
#              City   Longitude   Latitude  target  Has Table booking  \
# 0     Makati City  121.027535  14.565443    1100                  1
# 1     Makati City  121.014101  14.553708    1200                  1
# 2       Brasí_lia  -47.915667 -15.831000      80                  0
# 3       Brasí_lia  -47.910167 -15.827333     200                  0
# 4  Rio de Janeiro  -43.227000 -22.984167     250                  0
#
#    Price range  Aggregate rating Rating text  Votes      Country       Cuisine
# 0            3               4.8   Excellent    314  Phillipines   1100.000000
# 1            3               4.5   Excellent    591  Phillipines  27488.235294
# 2            3               3.1     Average     10       Brazil  27488.235294
# 3            4               3.7        Good      5       Brazil  27488.235294
# 4            4               4.6   Excellent     25       Brazil  27488.235294

# %%
#Encoding the Test Data
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder


# encoding the categorical variables
encoder = preprocessing.LabelEncoder()
df['City'] = encoder.fit_transform(df['City'])
df['Rating text'] = encoder.fit_transform(df['Rating text'])
df['Country'] = encoder.fit_transform(df['Country'])

# %%
df
# Out:
#       City   Longitude   Latitude  target  Has Table booking  Price range  \
# 0       73  121.027535  14.565443    1100                  1            3
# 1       73  121.014101  14.553708    1200                  1            3
# 2       21  -47.915667 -15.831000      80                  0            3
# 3       21  -47.910167 -15.827333     200                  0            4
# 4      110  -43.227000 -22.984167     250                  0            4
# ...    ...         ...        ...     ...                ...          ...
# 9537   139   29.036019  41.057979     120                  0            4
# 9538   139   28.977636  41.022904      40                  0            2
# 9539   139   28.981103  41.025785      90                  0            3
# 9540   139   29.041297  41.009847     105                  0            3
# 9541   139   29.034640  41.055817     170                  0            4
#
#       Aggregate rating  Rating text  Votes  Country       Cuisine
# 0                  4.8            1    314        6   1100.000000
# 1                  4.5            1    591        6  27488.235294
# 2                  3.1            0     10        1  27488.235294
# 3                  3.7            2      5        1  27488.235294
# 4                  4.6            1     25        1  27488.235294
# ...                ...          ...    ...      ...           ...
# 9537               4.0            5    901       11    100.000000
# 9538               4.7            1   1305       11     40.000000
# 9539               4.3            5    870       11     90.000000
# 9540               4.2            5   1034       11    105.000000
# 9541               3.7            2    661       11    170.000000
#
# [9542 rows x 11 columns]

# %%
df.drop(columns=['Longitude','Latitude'],inplace=True)

# %%
features = df.drop('target', axis=1)
target= df['target']

# %%
features.head()
# Out:
#    City  Has Table booking  Price range  Aggregate rating  Rating text  Votes  \
# 0    73                  1            3               4.8            1    314
# 1    73                  1            3               4.5            1    591
# 2    21                  0            3               3.1            0     10
# 3    21                  0            4               3.7            2      5
# 4   110                  0            4               4.6            1     25
#
#    Country       Cuisine
# 0        6   1100.000000
# 1        6  27488.235294
# 2        1  27488.235294
# 3        1  27488.235294
# 4        1  27488.235294

# %% [markdown]
# # Build Model -Average Cost for Two People

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

lr=LinearRegression() # instance for linearregression

# Find the best random state value where training r2-score = testing r2-score

Random_State=[]
Training_r2_score=[]
Testing_r2_score=[]
Difference=[]

# Get the random state value where training r2-score = testing r2-score

for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    
    if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
        Random_State.append(i)
        Training_r2_score.append(r2_score(y_train,pred_train)*100)
        Testing_r2_score.append(r2_score(y_test,pred_test)*100)
        Difference.append(abs((r2_score(y_test,pred_test)*100)-(r2_score(y_train,pred_train)*100)))

RS_table=pd.DataFrame({"Random State":Random_State,"Training R2 Score":Training_r2_score,"Testing R2 Score":Testing_r2_score,"Difference in R2 Score":Difference})
print("Table of random state values with training r2_score = testing r2_score")
RS_table.sort_values(by=["Difference in R2 Score"],ascending=True)
# Out:
# Table of random state values with training r2_score = testing r2_score
#    Random State  Training R2 Score  Testing R2 Score  Difference in R2 Score
# 0           774          64.113304         64.103675                0.009629

# %%
# best random state where training r2 score equal to testing r2 score
RSN=RS_table["Random State"][RS_table["Difference in R2 Score"]==RS_table["Difference in R2 Score"].min()]
BestRandomState=np.array(RSN)[0]
print("BestRandom State from Linear Regression",BestRandomState)
# Out:
# BestRandom State from Linear Regression 774

# %%
# Use the best random state and splitting the data
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=BestRandomState)

# %%
# Train the model and checkg  metrics with fixed random state
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print("Model : Linear Regression")
print("R2 Score : ",r2_score(y_test,pred_test))
print("Mean Absolute Error(MAE) : ",mean_absolute_error(y_test,pred_test))
print("Mean Squared Error(MSE) : ",mean_squared_error(y_test,pred_test))
print("Root Mean Squared Error(RMSE) : ",np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# Model : Linear Regression
# R2 Score :  0.6410367521286274
# Mean Absolute Error(MAE) :  719.7872450940405
# Mean Squared Error(MSE) :  46998828.91123026
# Root Mean Squared Error(RMSE) :  6855.569189442278

# %% [markdown]
# # Cross Validation for Linear Regression

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection  import cross_val_score
lss=r2_score(y_test,pred_lr)

# Find the optimized folds from Linear Regression where the cross validation score is same as model score

No_of_Folds=[]
CV_Score=[]
Model_Score=[]
Difference=[]

for j in range(2,11):
    lsscore=cross_val_score(lr,features,target,cv=j)
    lsc=lsscore.mean()
    No_of_Folds.append(j)
    CV_Score.append(lsc*100)
    Model_Score.append(lss*100)
    Difference.append(abs(lsc-lss))
CV_table=pd.DataFrame({"No of Folds":No_of_Folds,"Cross Validation R2 Score":CV_Score,"Model R2 Score":Model_Score,"Difference in R2 Score":Difference})  
print("Cross Validation Details with Folds")
CV_table.sort_values(by=["Difference in R2 Score"],ascending=True)
# Out:
# Cross Validation Details with Folds
#    No of Folds  Cross Validation R2 Score  Model R2 Score  \
# 0            2                  51.025950       64.103675
# 8           10                 -23.005408       64.103675
# 7            9                 -23.804740       64.103675
# 5            7                 -24.989065       64.103675
# 4            6                 -33.889383       64.103675
# 3            5                 -36.666076       64.103675
# 6            8                 -36.668615       64.103675
# 2            4                 -45.636566       64.103675
# 1            3                 -46.563230       64.103675
#
#    Difference in R2 Score
# 0                0.130777
# 8                0.871091
# 7                0.879084
# 5                0.890927
# 4                0.979931
# 3                1.007698
# 6                1.007723
# 2                1.097402
# 1                1.106669

# %%
# Get best no. of folds where the least difference between cross validation score & model score
CVF=CV_table["No of Folds"][CV_table["Difference in R2 Score"]==CV_table["Difference in R2 Score"].min()]
BCV=np.array(CVF)[0]
print("Best Cross Validation score is :",BCV)
# Out:
# Best Cross Validation score is : 2

# %%
# Use best CV value and checking the cross validation score again to compare with model score
lsscore_selected=cross_val_score(lr,features,target,cv=BCV).mean()
print("The CV r2 score is:",lsscore_selected*100,"\nThe model r2 score is:",lss*100)
print("Difference is:",lss-lsscore_selected)
# Out:
# The CV r2 score is: 51.025950142977926
# The model r2 score is: 64.10367521286274
# Difference is: 0.13077725069884816

# %% [markdown]
# # Other Regression Algorithms

# %%
from sklearn.tree import DecisionTreeRegressor          # DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor       # KNeighborsRegressor
from sklearn.linear_model import SGDRegressor           # Gradient Descent Regressor
from sklearn.svm import SVR                             # Support Vector Regressor
from sklearn.linear_model import Lasso                  # Lasso Regressor
from sklearn.linear_model import Ridge                  # Ridge Regressor
from sklearn.linear_model import ElasticNet             # Elastic Net Regressor
from sklearn.ensemble import RandomForestRegressor      # RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor        # ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor  # GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor          # AdaBoostRegressor
from xgboost import XGBRegressor                        # XGBRegressor

# list of all Algorithms

models=[('DecisionTreeRegressor()',DecisionTreeRegressor()),('KNeighborsRegressor()',KNeighborsRegressor()),
        ('SGDRegressor()',SGDRegressor()),('SVR()',SVR()),('Lasso()',Lasso()),('Ridge()',Ridge()),
        ('ElasticNet()',ElasticNet()),('RandomForestRegressor()',RandomForestRegressor()),
        ('ExtraTreesRegressor()',ExtraTreesRegressor()),('GradientBoostingRegressor()',GradientBoostingRegressor()),
        ('AdaBoostRegressor()',AdaBoostRegressor()),('XGBRegressor()',XGBRegressor())]

#  empty lists
Model=[lr]
CV_Score=[lsscore_selected*100]
Model_Score=[lss*100]
Difference=[abs(lss-lsscore_selected)]
MAE=[mean_absolute_error(y_test,pred_lr)]
MSE=[mean_squared_error(y_test,pred_lr)]
RMSE=[np.sqrt(mean_squared_error(y_test,pred_lr))]

# Loop  all algorithms to train the model & check for the cross validation
for model in models:
    model[1].fit(x_train,y_train)                             # Train the model
    pred_test=model[1].predict(x_test)                        # Predict Y values from the model using X test
    Model_Score.append(r2_score(y_test,pred_test)*100)        # "R2 Score" to the list 
    MAE.append(mean_absolute_error(y_test,pred_test))         #  "MAE" to the list 
    MSE.append(mean_squared_error(y_test,pred_test))          #  "MSE" to the list 
    RMSE.append(np.sqrt(mean_squared_error(y_test,pred_test)))#  "RMSE" to the list 
    
    score=cross_val_score(model[1],features,target,cv=BCV).mean()         # Cross Validation mean score calculation
    CV_Score.append(score*100)                                #  "cross validation score" to the list
    Difference.append(abs(r2_score(y_test,pred_test)-score)) # "Difference b/w CV and model scores" to the list
    Model.append(model[0])                                    #  "Model" to the list

#e dataframe with scores and the differences
score_table=pd.DataFrame({'Model':Model,'Model R2 Score':Model_Score,'Cross Validation R2 Score':CV_Score,'Difference in R2 Score':Difference,'MAE':MAE,'MSE':MSE,'RMSE':RMSE})
print("DataFrame with all model metrics")
score_table[score_table["Difference in R2 Score"]<100].sort_values(by=["Difference in R2 Score"],ascending=True)
# Out:
# DataFrame with all model metrics
#                           Model  Model R2 Score  Cross Validation R2 Score  \
# 4                         SVR()       -0.114069                  -0.198604
# 10  GradientBoostingRegressor()       45.288744                  44.405392
# 11          AdaBoostRegressor()       39.096069                  41.054015
# 12               XGBRegressor()       24.863056                  29.879679
# 8       RandomForestRegressor()       59.820285                  49.314611
# 9         ExtraTreesRegressor()       41.762150                  53.215391
# 0            LinearRegression()       64.103675                  51.025950
# 6                       Ridge()       64.103799                  51.025890
# 5                       Lasso()       64.105671                  51.026538
# 7                  ElasticNet()       64.170363                  51.020712
# 2         KNeighborsRegressor()       56.795980                  29.973162
# 1       DecisionTreeRegressor()       74.950847                  37.069425
#
#     Difference in R2 Score          MAE           MSE          RMSE
# 4                 0.000845   589.804505  1.310787e+08  11448.961179
# 10                0.008834   523.895478  7.163310e+07   8463.633857
# 11                0.019579  1033.721206  7.974113e+07   8929.788795
# 12                0.050166   435.452340  9.837632e+07   9918.483801
# 8                 0.105057   427.687043  5.260704e+07   7253.071404
# 9                 0.114532   528.367055  7.625045e+07   8732.150130
# 0                 0.130777   719.787245  4.699883e+07   6855.569189
# 6                 0.130779   719.691073  4.699867e+07   6855.557359
# 5                 0.130791   718.515271  4.699622e+07   6855.378575
# 7                 0.131497   657.374778  4.691152e+07   6849.198177
# 2                 0.268228   478.493557  5.656675e+07   7521.086867
# 1                 0.378814   242.187583  3.279670e+07   5726.839935

# %% [markdown]
# ## Observations:
# Best model( Ridge Regression) for this dataset because of:
#
# 1.highest R^2 score
#
# 2.lowest root mean squared error
#
# Out of all algorithms checked, Ridge Regression model is selected for hyper parameter tuning
#
# as the difference between model and cross-validation score is less

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#Hyper Parameter Tuning
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# Defining parameters for Ridge
parameters = {
     'alpha': [1.0,2.0],    
    'max_iter': [1,3],      
    'solver': ['lsqr','sag'],    
    'fit_intercept': [True, False]      
    }

GCV=GridSearchCV(Ridge(),parameters,cv=5)  
GCV.fit(x_train,y_train)   #  GridSearchCV to train model with all combination of parameters
GCV.best_params_
# Out:
# {'alpha': 1.0, 'fit_intercept': False, 'max_iter': 3, 'solver': 'sag'}

# %%
ExReg=Ridge(alpha=GCV.best_params_['alpha']
                        ,max_iter=GCV.best_params_['max_iter'],
                   solver=GCV.best_params_['solver'],fit_intercept=GCV.best_params_['fit_intercept']
                        )
ExReg.fit(x_train,y_train)
ExReg.score(x_train,y_train)
pred_decision=ExReg.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print("R2 Score:",rfs*100)

rfscore=cross_val_score(ExReg,features,target,cv=2)
rfc=rfscore.mean()
print("Cross Val Score:",rfc*100)
print("Difference is:",r2_score(y_test,pred_decision)-rfc)
# Out:
# R2 Score: 60.48589636238242
# Cross Val Score: 39.99766483234648
# Difference is: 0.20488231530035939

# %% [markdown]
# ## Observations:
# Hyper Parameter Tuned model: The difference between Cross Validation Score and model score is 0.204
#
# Model with default parameters: The difference between Cross Validation Score and model score is 0.130
#
# As difference is less in the model with default parameters We will consider the Ridge Regression model with default parameters

# %%
#models selected ===RidgeRegression()
# x_predict = list(ExReg.predict(x_test))
x_predict = list(models[5][1].predict(x_test))
predicted_df = {'predicted_values': x_predict, 'original_values': y_test}
#creating new dataframe
pd.DataFrame(predicted_df).head(10)
# Out:
#       predicted_values  original_values
# 3973       -398.263074              800
# 5203        489.975964             1400
# 9061       1022.674312             2000
# 3188        363.170052              600
# 2652        932.493192              350
# 5672        944.581956              800
# 1835        534.289932              500
# 5490       1982.158923              400
# 3291        285.384394              300
# 2852        430.395098              450

# %% [markdown]
# # Save Model --Average Cost for Two People

# %%
#RidgeRegression()
import pickle
file = 'AvgCostTwo_predict'
Final_mod =models[5][1]
print(Final_mod)
save = pickle.dump(ExReg,open('AvgCostTwo_predict.pkl','wb'))
# Out:
# Ridge()

# %%
# Prediction
prediction = Final_mod.predict(x_test)
y_pred=Final_mod.predict(x_test)
print('\033[1m'+'Model Score :'+'\033[0m\n', r2_score(y_test, y_pred))
# Out:
# Model Score :
#  0.6410379909963146

# %% [markdown]
# # Conclusion --Average Cost for Two People

# %%
pickled_AvgCostTwo_predict = pickle.load(open('AvgCostTwo_predict.pkl','rb'))
result=pickled_AvgCostTwo_predict.score(x_test,y_test)
print(result)

conclusion=pd.DataFrame([pickled_AvgCostTwo_predict.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion.T
# Out:
# 0.6048589636238242
#         Predicted  Original
# 0      539.667266     800.0
# 1      625.586338    1400.0
# 2     1734.119336    2000.0
# 3      359.085383     600.0
# 4      671.789177     350.0
# ...           ...       ...
# 1904   433.508070     500.0
# 1905   294.118453     500.0
# 1906   694.317951     800.0
# 1907   359.098381     350.0
# 1908   359.085683     200.0
#
# [1909 rows x 2 columns]

# %% [markdown]
# # Build Model -- Price Range

# %%
features = df.drop('Price range', axis=1)
target= df['Price range']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

lr=LinearRegression() # instance for linearregression

# Find the best random state value where training r2-score = testing r2-score

Random_State=[]
Training_r2_score=[]
Testing_r2_score=[]
Difference=[]

# Get the random state value where training r2-score = testing r2-score

for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    
    if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
        Random_State.append(i)
        Training_r2_score.append(r2_score(y_train,pred_train)*100)
        Testing_r2_score.append(r2_score(y_test,pred_test)*100)
        Difference.append(abs((r2_score(y_test,pred_test)*100)-(r2_score(y_train,pred_train)*100)))

RS_table=pd.DataFrame({"Random State":Random_State,"Training R2 Score":Training_r2_score,"Testing R2 Score":Testing_r2_score,"Difference in R2 Score":Difference})
print("Table of random state values with training r2_score = testing r2_score")
RS_table.sort_values(by=["Difference in R2 Score"],ascending=True)
# Out:
# Table of random state values with training r2_score = testing r2_score
#     Random State  Training R2 Score  Testing R2 Score  Difference in R2 Score
# 11           954          43.235794         43.239005                0.003211
# 9            567          43.237263         43.230007                0.007256
# 7            446          43.237262         43.245193                0.007931
# 3            165          43.231194         43.239914                0.008720
# 10           629          43.238537         43.249208                0.010671
# 6            223          43.247928         43.229613                0.018315
# 2            142          43.250393         43.269565                0.019172
# 0             28          43.225529         43.246337                0.020808
# 8            458          43.229173         43.202507                0.026666
# 1             76          43.255846         43.289686                0.033839
# 4            167          43.250023         43.290130                0.040106
# 5            202          43.227168         43.186076                0.041092

# %%
# best random state where training r2 score equal to testing r2 score
RSN=RS_table["Random State"][RS_table["Difference in R2 Score"]==RS_table["Difference in R2 Score"].min()]
BestRandomState=np.array(RSN)[0]
print("BestRandom State from Linear Regression",BestRandomState)
# Out:
# BestRandom State from Linear Regression 954

# %%
# Use the best random state and splitting the data
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=BestRandomState)

# %%
# Train the model and checkg  metrics with fixed random state
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print("Model : Linear Regression")
print("R2 Score : ",r2_score(y_test,pred_test))
print("Mean Absolute Error(MAE) : ",mean_absolute_error(y_test,pred_test))
print("Mean Squared Error(MSE) : ",mean_squared_error(y_test,pred_test))
print("Root Mean Squared Error(RMSE) : ",np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# Model : Linear Regression
# R2 Score :  0.4323900527366822
# Mean Absolute Error(MAE) :  0.54452264812187
# Mean Squared Error(MSE) :  0.4657653048917827
# Root Mean Squared Error(RMSE) :  0.6824700029245114

# %% [markdown]
# # Cross Validation for Linear Regression

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection  import cross_val_score
lss=r2_score(y_test,pred_lr)

# Find the optimized folds from Linear Regression where the cross validation score is same as model score

No_of_Folds=[]
CV_Score=[]
Model_Score=[]
Difference=[]

for j in range(2,11):
    lsscore=cross_val_score(lr,features,target,cv=j)
    lsc=lsscore.mean()
    No_of_Folds.append(j)
    CV_Score.append(lsc*100)
    Model_Score.append(lss*100)
    Difference.append(abs(lsc-lss))
CV_table=pd.DataFrame({"No of Folds":No_of_Folds,"Cross Validation R2 Score":CV_Score,"Model R2 Score":Model_Score,"Difference in R2 Score":Difference})  
print("Cross Validation Details with Folds")
CV_table.sort_values(by=["Difference in R2 Score"],ascending=True)
# Out:
# Cross Validation Details with Folds
#    No of Folds  Cross Validation R2 Score  Model R2 Score  \
# 5            7                  36.395857       43.239005
# 4            6                  36.233504       43.239005
# 7            9                  35.989503       43.239005
# 3            5                  35.052713       43.239005
# 0            2                  34.356614       43.239005
# 8           10                  34.185426       43.239005
# 1            3                  33.680490       43.239005
# 6            8                  29.171808       43.239005
# 2            4                  28.938904       43.239005
#
#    Difference in R2 Score
# 5                0.068431
# 4                0.070055
# 7                0.072495
# 3                0.081863
# 0                0.088824
# 8                0.090536
# 1                0.095585
# 6                0.140672
# 2                0.143001

# %%
# Get best no. of folds where the least difference between cross validation score & model score
CVF=CV_table["No of Folds"][CV_table["Difference in R2 Score"]==CV_table["Difference in R2 Score"].min()]
BCV=np.array(CVF)[0]
print("Best Cross Validation score is :",BCV)
# Out:
# Best Cross Validation score is : 7

# %%
# Use best CV value and checking the cross validation score again to compare with model score
lsscore_selected=cross_val_score(lr,features,target,cv=BCV).mean()
print("The CV r2 score is:",lsscore_selected*100,"\nThe model r2 score is:",lss*100)
print("Difference is:",lss-lsscore_selected)
# Out:
# The CV r2 score is: 36.395856611515136
# The model r2 score is: 43.23900527366822
# Difference is: 0.06843148662153081

# %% [markdown]
# # Other Regression Algorithms

# %%
from sklearn.tree import DecisionTreeRegressor          # DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor       # KNeighborsRegressor
from sklearn.linear_model import SGDRegressor           # Gradient Descent Regressor
from sklearn.svm import SVR                             # Support Vector Regressor
from sklearn.linear_model import Lasso                  # Lasso Regressor
from sklearn.linear_model import Ridge                  # Ridge Regressor
from sklearn.linear_model import ElasticNet             # Elastic Net Regressor
from sklearn.ensemble import RandomForestRegressor      # RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor        # ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor  # GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor          # AdaBoostRegressor
from xgboost import XGBRegressor                        # XGBRegressor

# list of all Algorithms

models=[('DecisionTreeRegressor()',DecisionTreeRegressor()),('KNeighborsRegressor()',KNeighborsRegressor()),
        ('SGDRegressor()',SGDRegressor()),('SVR()',SVR()),('Lasso()',Lasso()),('Ridge()',Ridge()),
        ('ElasticNet()',ElasticNet()),('RandomForestRegressor()',RandomForestRegressor()),
        ('ExtraTreesRegressor()',ExtraTreesRegressor()),('GradientBoostingRegressor()',GradientBoostingRegressor()),
        ('AdaBoostRegressor()',AdaBoostRegressor()),('XGBRegressor()',XGBRegressor())]

#  empty lists
Model=[lr]
CV_Score=[lsscore_selected*100]
Model_Score=[lss*100]
Difference=[abs(lss-lsscore_selected)]
MAE=[mean_absolute_error(y_test,pred_lr)]
MSE=[mean_squared_error(y_test,pred_lr)]
RMSE=[np.sqrt(mean_squared_error(y_test,pred_lr))]

# Loop  all algorithms to train the model & check for the cross validation
for model in models:
    model[1].fit(x_train,y_train)                             # Train the model
    pred_test=model[1].predict(x_test)                        # Predict Y values from the model using X test
    Model_Score.append(r2_score(y_test,pred_test)*100)        # "R2 Score" to the list 
    MAE.append(mean_absolute_error(y_test,pred_test))         #  "MAE" to the list 
    MSE.append(mean_squared_error(y_test,pred_test))          #  "MSE" to the list 
    RMSE.append(np.sqrt(mean_squared_error(y_test,pred_test)))#  "RMSE" to the list 
    
    score=cross_val_score(model[1],features,target,cv=BCV).mean()         # Cross Validation mean score calculation
    CV_Score.append(score*100)                                #  "cross validation score" to the list
    Difference.append(abs(r2_score(y_test,pred_test)-score)) # "Difference b/w CV and model scores" to the list
    Model.append(model[0])                                    #  "Model" to the list

#e dataframe with scores and the differences
score_table=pd.DataFrame({'Model':Model,'Model R2 Score':Model_Score,'Cross Validation R2 Score':CV_Score,'Difference in R2 Score':Difference,'MAE':MAE,'MSE':MSE,'RMSE':RMSE})
print("DataFrame with all model metrics")
score_table[score_table["Difference in R2 Score"]<100].sort_values(by=["Difference in R2 Score"],ascending=True)
# Out:
# DataFrame with all model metrics
#                           Model  Model R2 Score  Cross Validation R2 Score  \
# 4                         SVR()       43.758459                  44.995774
# 12               XGBRegressor()       98.803748                  97.454381
# 8       RandomForestRegressor()       98.618885                  97.092114
# 10  GradientBoostingRegressor()       97.286907                  95.674496
# 2         KNeighborsRegressor()       78.537780                  76.667117
# 1       DecisionTreeRegressor()       97.701844                  95.222842
# 9         ExtraTreesRegressor()       96.691582                  93.813589
# 11          AdaBoostRegressor()       80.367887                  76.955287
# 6                       Ridge()       43.234783                  36.393907
# 0            LinearRegression()       43.239005                  36.395857
# 5                       Lasso()        9.736563                  -1.427489
# 7                  ElasticNet()        9.932432                  -1.264968
#
#     Difference in R2 Score       MAE       MSE      RMSE
# 4                 0.012373  0.429287  0.461503  0.679340
# 12                0.013494  0.027137  0.009816  0.099076
# 8                 0.015268  0.024788  0.011333  0.106457
# 10                0.016124  0.059286  0.022263  0.149208
# 2                 0.018707  0.142169  0.176113  0.419658
# 1                 0.024790  0.018858  0.018858  0.137325
# 9                 0.028780  0.050545  0.027148  0.164766
# 11                0.034126  0.325555  0.161096  0.401367
# 6                 0.068409  0.544535  0.465800  0.682495
# 0                 0.068431  0.544523  0.465765  0.682470
# 5                 0.111641  0.707373  0.740677  0.860626
# 7                 0.111974  0.705630  0.739070  0.859692

# %% [markdown]
# ## Observations:
# Best model( XGBRegressor()	) for this dataset because of:
#
# 1.highest R^2 score
#
# 2.lowest root mean squared error
#
# Out of all algorithms checked,XGBRegressor()model is selected for hyper parameter tuning
#
# as the difference between model and cross-validation score is less

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#Hyper Parameter Tuning XGBRegressor()
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# Defining parameters for XGBRegressor()
parameters = {           
             'max_depth': [5,10], 
              'min_child_weight': [1,5], 
              'learning_rate':[0.1,0.9],
              'n_estimators': [5,10]
    
    }

GCV=GridSearchCV(XGBRegressor(),parameters,cv=5)  
GCV.fit(x_train,y_train)   #  GridSearchCV to train model with all combination of parameters
GCV.best_params_
# Out:
# {'learning_rate': 0.9,
#  'max_depth': 5,
#  'min_child_weight': 5,
#  'n_estimators': 10}

# %%
Rdg=XGBRegressor(max_depth=GCV.best_params_['max_depth'],
                 min_child_weight=GCV.best_params_['min_child_weight'],
                   learning_rate=GCV.best_params_['learning_rate'],n_estimators=GCV.best_params_['n_estimators'])
Rdg.fit(x_train,y_train)
Rdg.score(x_train,y_train)
pred_decision=Rdg.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print("R2 Score:",rfs*100)

rfscore=cross_val_score(Rdg,features,target,cv=2)
rfc=rfscore.mean()
print("Cross Val Score:",rfc*100)
print("Difference is:",r2_score(y_test,pred_decision)-rfc)
# Out:
# R2 Score: 97.33772308310476
# Cross Val Score: 85.73993261238779
# Difference is: 0.11597790470716973

# %% [markdown]
# ## Observations:
# Hyper Parameter Tuned model: The difference between Cross Validation Score and model score is 0.115
#
# Model with default parameters: The difference between Cross Validation Score and model score is 0.013
#
# As difference is less in the model with default parameters We will consider the Ridge Regression model with default parameters

# %%
#models selected ===XGBRegressor()
x_predict = list(models[11][1].predict(x_test))
predicted_df = {'predicted_values': x_predict, 'original_values': y_test}
#creating new dataframe
pd.DataFrame(predicted_df).head(10)
# Out:
#       predicted_values  original_values
# 1729          1.959515                2
# 7496          0.999995                1
# 1728          2.986516                3
# 9264          1.998444                2
# 6181          0.999870                1
# 428           2.009022                2
# 7575          2.028453                2
# 1199          1.007667                1
# 2084          3.999245                4
# 3550          0.999785                1

# %%
#XGBRegresser()
import pickle
file = 'pricerange_predict'
Final_mod = models[11][1]
print(Final_mod)
save = pickle.dump(Rdg,open('pricerange_predict.pkl','wb'))
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
# Prediction
prediction = Final_mod.predict(x_test)
y_pred=Final_mod.predict(x_test)
print('\033[1m'+'r2 Score :'+'\033[0m\n', r2_score(y_test, y_pred))
# Out:
# r2 Score :
#  0.9880374760681401

# %% [markdown]
# # Conclusion- Price Range

# %%
pickled_pricerange_predict = pickle.load(open('pricerange_predict.pkl','rb'))
result=pickled_pricerange_predict.score(x_test,y_test)
print(result)

conclusion=pd.DataFrame([pickled_pricerange_predict.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion.T
# Out:
# 0.9733772308310477
#       Predicted  Original
# 0      1.974859       2.0
# 1      0.999068       1.0
# 2      3.056916       3.0
# 3      1.999679       2.0
# 4      1.003443       1.0
# ...         ...       ...
# 1904   1.010133       1.0
# 1905   1.001870       1.0
# 1906   0.999068       1.0
# 1907   0.999068       1.0
# 1908   1.998106       2.0
#
# [1909 rows x 2 columns]
